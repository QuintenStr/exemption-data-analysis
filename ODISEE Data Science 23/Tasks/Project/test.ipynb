# %%
# Plaats ALLE imports hier

from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.svm import SVC

import matplotlib.pyplot as plt
import numpy as np
import opendatasets as od
import pandas as pd
import seaborn as sns
import sqlite3

# %%
df = pd.read_csv('F:\Github\project-lorenzo-quinten\getrainde_modellen.csv')
df.sort_values(by="mean_test_score", ascending=False, inplace=True)
display(df.head(50))
# Out:
#                       techniek  model_no  mean_fit_time  mean_test_score  \
# 373  Logistic Regression (LOR)        59       0.476459         0.535848
# 382  Logistic Regression (LOR)        68       0.442829         0.535714
# 386  Logistic Regression (LOR)        72       0.935258         0.535714
# 385  Logistic Regression (LOR)        71       0.915815         0.535714
# 384  Logistic Regression (LOR)        70       0.924445         0.535714
# 383  Logistic Regression (LOR)        69       0.913137         0.535714
# 407  Logistic Regression (LOR)        93       7.394172         0.535714
# 381  Logistic Regression (LOR)        67       0.556810         0.535647
# 391  Logistic Regression (LOR)        77       6.890137         0.535647
# 379  Logistic Regression (LOR)        65       0.804711         0.535647
# 380  Logistic Regression (LOR)        66       0.693706         0.535647
# 398  Logistic Regression (LOR)        84       0.426560         0.535647
# ...

# %%
grouped_df = df.groupby("techniek")
aggregated_df = grouped_df.agg({"mean_fit_time": ["mean", "median","min", "max"], "mean_test_score": ["mean", "median","min", "max"]})
a = aggregated_df["mean_fit_time"].reset_index()
display(a)
a.to_csv('out.zip', index=True)
# Out:
#                             techniek       mean     median       min  \
# 0  C-Support Vector Classifier (SVC)  20.481589  12.983796  6.125701
# 1       K-Neighbors Classifier (KNN)   0.064779   0.047657  0.005158
# 2          Logistic Regression (LOR)   0.706398   0.418228  0.063389
# 3     Random Forest Classifier (RFC)   1.842068   1.688828  0.610477
#
#          max
# 0  61.803508
# 1   0.161596
# 2   7.394172
# 3   6.415167
